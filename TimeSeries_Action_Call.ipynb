# %%
import numpy as np
import pandas as pd

# %%
c_v = pd.read_excel("/content/TimeSeries_Action_Call.xlsx")

# %%
c_v
# Out:
#                Returnees  ...  Follow-up calls inpast 24 hrs
# 0    Returnees from Iran  ...                            353
# 1   Returnees from China  ...                            400
# 2    Returnees from Iran  ...                            668
# 3   Returnees from China  ...                            109
# 4    Returnees from Iran  ...                            632
# 5   Returnees from China  ...                            186
# 6    Returnees from Iran  ...                            329
# 7   Returnees from China  ...                             42
# 8    Returnees from Iran  ...                            443
# 9   Returnees from China  ...                             77
# 10   Returnees from Iran  ...                              0
# 11  Returnees from China  ...                              0
# 12   Returnees from Iran  ...                            438
# 13  Returnees from China  ...                             20
# ...

# %%
c_v.rename(columns = {'Advised Self-Quarantine':'Advised_Self_Quarantine','Cumulative no offirst-time calls':'Cumulative_no_offirst_time_calls',
                   'Cumulativefollow-up calls':'Cumulative_follow_up_calls','First-time calls inpast 24 hrs':'First_time_calls_inpast_24_hrs',
                    'Follow-up calls inpast 24 hrs':'Follow_up_calls_inpast_24_hrs'
                    },inplace=True)

# %%
c_v
# Out:
#                Returnees  ...  Follow_up_calls_inpast_24_hrs
# 0    Returnees from Iran  ...                            353
# 1   Returnees from China  ...                            400
# 2    Returnees from Iran  ...                            668
# 3   Returnees from China  ...                            109
# 4    Returnees from Iran  ...                            632
# 5   Returnees from China  ...                            186
# 6    Returnees from Iran  ...                            329
# 7   Returnees from China  ...                             42
# 8    Returnees from Iran  ...                            443
# 9   Returnees from China  ...                             77
# 10   Returnees from Iran  ...                              0
# 11  Returnees from China  ...                              0
# 12   Returnees from Iran  ...                            438
# 13  Returnees from China  ...                             20
# ...

# %%
c_v.drop('number',axis=1,inplace=True)

# %%
c_v.head()
# Out:
#               Returnees  ...  Follow_up_calls_inpast_24_hrs
# 0   Returnees from Iran  ...                            353
# 1  Returnees from China  ...                            400
# 2   Returnees from Iran  ...                            668
# 3  Returnees from China  ...                            109
# 4   Returnees from Iran  ...                            632
#
# [5 rows x 7 columns]

# %%
c_v
# Out:
#                Returnees  ...  Follow_up_calls_inpast_24_hrs
# 0    Returnees from Iran  ...                            353
# 1   Returnees from China  ...                            400
# 2    Returnees from Iran  ...                            668
# 3   Returnees from China  ...                            109
# 4    Returnees from Iran  ...                            632
# 5   Returnees from China  ...                            186
# 6    Returnees from Iran  ...                            329
# 7   Returnees from China  ...                             42
# 8    Returnees from Iran  ...                            443
# 9   Returnees from China  ...                             77
# 10   Returnees from Iran  ...                              0
# 11  Returnees from China  ...                              0
# 12   Returnees from Iran  ...                            438
# 13  Returnees from China  ...                             20
# ...

# %%
c_v.columns
# Out:
# Index(['Returnees', 'Advised_Self_Quarantine',
#        'Cumulative_no_offirst_time_calls', 'Cumulative_follow_up_calls',
#        'Date', 'First_time_calls_inpast_24_hrs',
#        'Follow_up_calls_inpast_24_hrs'],
#       dtype='object')

# %%
c_v.values
# Out:
# array([['Returnees from Iran', 0, 9459, 2553, '11-Mar-2020', 0, 353],
#        ['Returnees from China', 11, 5342, 7746, '11-Mar-2020', 17, 400],
#        ['Returnees from Iran', 14, 9475, 3221, '12-Mar-2020', 16, 668],
#        ['Returnees from China', 7, 5352, 7855, '12-Mar-2020', 10, 109],
#        ['Returnees from Iran', 0, 9475, 3853, '13-Mar-2020', 0, 632],
#        ['Returnees from China', 10, 5362, 8041, '13-Mar-2020', 10, 186],
#        ['Returnees from Iran', 3, 9480, 4182, '14-Mar-2020', 5, 329],
#        ['Returnees from China', 5, 5370, 8083, '14-Mar-2020', 8, 42],
#        ['Returnees from Iran', 0, 9480, 4625, '15-Mar-2020', 0, 443],
#        ['Returnees from China', 0, 5370, 8160, '15-Mar-2020', 0, 77],
#        ['Returnees from Iran', 3, 9488, 4625, '16-Mar-2020', 8, 0],
#        ['Returnees from China', 11, 5394, 8160, '16-Mar-2020', 24, 0],
#        ['Returnees from Iran', 0, 9488, 5063, '17-Mar-2020', 0, 438],
# ...

# %%
c_v.index
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %%
c_v['Returnees'] = c_v.Returnees.astype(str)

# %%
c_v.dtypes
# Out:
# Returnees                           object
# Advised_Self_Quarantine              int64
# Cumulative_no_offirst_time_calls     int64
# Cumulative_follow_up_calls           int64
# Date                                object
# First_time_calls_inpast_24_hrs       int64
# Follow_up_calls_inpast_24_hrs        int64
# dtype: object

# %%
c_v['Date']=pd.to_datetime(c_v.Date)

# %%
c_v['Date']
# Out:
# 0    2020-03-11
# 1    2020-03-11
# 2    2020-03-12
# 3    2020-03-12
# 4    2020-03-13
# 5    2020-03-13
# 6    2020-03-14
# 7    2020-03-14
# 8    2020-03-15
# 9    2020-03-15
# 10   2020-03-16
# 11   2020-03-16
# 12   2020-03-17
# 13   2020-03-17
# 14   2020-03-18
# 15   2020-03-18
# 16   2020-03-19
# 17   2020-03-19
# 18   2020-03-20
# 19   2020-03-20
# 20   2020-03-21
# 21   2020-03-21
# 22   2020-03-22
# 23   2020-03-22
# 24   2020-03-23
# 25   2020-03-23
# 26   2020-03-24
# 27   2020-03-24
# 28   2020-03-25
# 29   2020-03-25
# 30   2020-03-26
# 31   2020-03-26
# 32   2020-03-27
# 33   2020-03-27
# 34   2020-03-28
# 35   2020-03-28
# 36   2020-03-29
# 37   2020-03-29
# 38   2020-03-30
# 39   2020-03-30
# Name: Date, dtype: datetime64[ns]

# %%
c_v.duplicated().any()
# Out:
# False

# %%
c_v.to_excel('/content/TimeSeries_Action_Call.xlsx') ##saving back to excel

# %%
c_v.describe() #data is cleaned
# Out:
#        Advised_Self_Quarantine  ...  Follow_up_calls_inpast_24_hrs
# count                40.000000  ...                      40.000000
# mean                  2.675000  ...                     257.025000
# std                   4.654127  ...                     197.717033
# min                   0.000000  ...                       0.000000
# 25%                   0.000000  ...                      94.250000
# 50%                   0.000000  ...                     250.500000
# 75%                   3.000000  ...                     404.000000
# max                  16.000000  ...                     719.000000
#
# [8 rows x 5 columns]
